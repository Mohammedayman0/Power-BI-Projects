# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# from bs4 import BeautifulSoup
# import requests
# import time
# import datetime

# import smtplib

# %%
# URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

# headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# page = requests.get(URL, headers=headers)

# soup1 = BeautifulSoup(page.content, "html.parser")

# soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

# title = soup2.find(id='productTitle').get_text()

# price = soup2.find(id='priceblock_ourprice').get_text()


# print(title)
# print(price)

# %%
#driver=webdriver.Firefox(executable_path='E:\Data\geckodriver-v0.34.0-win64\geckodriver.exe')
#driver=webdriver.Firefox(executable_path=r"‪E:\Data\geckodriver-v0.33.0-win642\geckodriver.exe")

# %%
driver=webdriver.Chrome()

driver.get("https://www.amazon.eg/s?k=samsung+phone&crid=5KAZKWTPF1EV&sprefix=samsung+phone%2Caps%2C204&ref=nb_sb_noss_1")

# %%
titles=driver.find_elements(By.XPATH,"//span[@class='a-size-base-plus a-color-base a-text-normal']")
for title in titles:
    print(title.text)
# Out:
# جراب موبايل متوافق مع سامسونج جالاكسي A15 جلوبال ماجيك شيلد من البولي يوريثين الحراري + جراب سيليكون مضاد للصدمات لموبايل سامسونج جالاكسي A15 (رمادي داكن)
# جراب موبايل متوافق مع سامسونج جالاكسي M51، جراب جلد متعددة الوظائف قابل للطي أفقيًا مع فتحة للبطاقات وحامل ومحفظة لموبايل سامسونج جالاكسي M51 (أسود)
# جراب حماية خلفي مغناطيسي من الجلد الفاخر من جيهود متوافق مع سامسونج جالاكسي S23 FE (بني)
# جراب موبايل متوافق مع سامسونج جالاكسي S23 FE شبكة الجيل الخامس 5G، جراب جلد افقي متعدد الوظائف، مع فتحة للبطاقات وحامل ومحفظة لسامسونج جالاكسي S23 FE 5G (أسود)
# موبايل سامسونج A04S ذاكرة رام 3 جيجابايت، ذاكرة داخلية 32 جيجابايت - لون أسود، سامسونج ايه 04 اس، شريحتين
# موبايل سامسونج جالاكسي A15 بشاشة 6.5 بوصة بشريحتين اتصال وذاكرة رام سعة 8 جيجابايت + ذاكرة ROM سعة 256 جيجابايت بشبكة الجيل الرابع 4G - (لون أسود)
# موبايل سامسونج جالاكسي A54 (5G) بشريحتين اتصال، نظام تشغيل اندرويد، ذاكرة RAM 8 جيجابايت، ذاكرة تخزين داخلية 128 جيجابايت، اوسيم رمادي جرافيت
# موبايل سامسونج جالاكسي A05 LTE بشريحتي اتصال، نظام تشغيل اندرويد، سعة تخزينية 128 جيجابايت، ذاكرة رام 6 جيجابايت، فضي
# موبايل سامسونج جالاكسي A05s، يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة رام سعة 4 جيحا، وذاكرة تخزين 128 جيجا، أسود
# موبايل سامسونج جالاكسي A05s، هاتف ذكي يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة RAM سعة 6 جيحا، وذاكرة تخزين 128 جيجا، أسود
# موبايل سامسونج جالاكسي A25 شبكة الجيل الخامس 5G بنظام اندرويد بشريحتين اتصال وذاكرة تخزين 128 جيجا وذاكرة رام سعة 6 جيجا، أسود
# سامسونج هاتف ذكي جالكسي زد فولد 5 بنظام اندرويد، ذاكرة رام 12 جيجا، ذاكرة روم 256 جيجا، اسود فانتوم - ضمان لمدة عام، بشريحتين
# موبايل سامسونج جالاكسي A15 بشاشة 6.5 بوصة بشريحتين شبكة الجيل الرابع 4G LTE وذاكرة رام سعة 8 جيجابايت + ذاكرة ROM سعة 256 جيجابايت - لون أزرق فاتح
# سامسونج هاتف ذكي جالكسي اس 23 اف اي 5G ثنائي شرائح الاتصال بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا - اخضر فاتح
# موبايل سامسونج جالاكسي A54 اندرويد بشريحتين اتصال - ذاكرة رام 8 جيجابايت - 128 جيجابايت - 5G - - لون اوسوم لايم
# موبايل سامسونج جالاكسي A15 بشريحتين اتصال وذاكرة رام بسعة 4 جيجابايت وذاكرة ROM بسعة 128 جيجابايت بشبكة الجيل الرابع 4G وشاشة حجم 6.5 بوصة - (لون اسود أزرق)
# موبايل سامسونج جالاكسي A34 شبكة الجيل الخامس 5G بشريحتين اتصال وذاكرة رام 8 جيجابايت وذاكرة داخلية 256 جيجابايت بلون فضي
# موبايل سامسونج جالاكسي S23 الترا، بذاكرة رام 12 جيجا، موبايل ذكي يعمل بنظام اندرويد بشريحتين اتصال لون أسود فانتوم
# موبايل سمارت سامسونج جالاكسي S24 الترا بنظام اندرويد بالذكاء الاصطناعي بذاكرة تخزين 256 جيجابايت وذاكرة رام 12 جيجابايت وكاميرا 200 ميجابيكسل بعمر بطارية طويل وقلم ستايلس، لون تيتانيوم بلاك، بشريحتين
# موبايل سامسونج جالاكسي A25 شبكة الجيل الخامس 5G، بنظام اندرويد، بشريحتين اتصال، ذاكرة رام سعة 8 جيحا، وذاكرة تخزين 256 جيجا، لون أزرق فاتح
# جراب موبايل متوافق مع سامسونج جالاكسي A15 [تصميم خلية النحل] حماية من السقوط، جراب حماية رفيع للغاية من البولي يوريثين الحراري + بولي كربونات سيليكون شفاف، جراب مضاد للصدمات لموبايل سامسونج جالاكسي
# جراب بانك ارمور 2 في 1 متوافق مع موبايل سامسونج جالاكسي S23، من البولي كربونات والبولي يوريثين المقاوم للحرارة مضاد للصدمات بحامل غير مرئي لموبايل سامسونج جالاكسي S23 FE (أسود)
# جراب خلفي مغناطيسي من الجلد الفاخر متوافق مع سامسونج جالاكسي S23 FE، جراب حماية مغناطيسي لموبايل سامسونج جالاكسي S23 FE (بني فاتح)
# جراب حماية غوريلا سيليكون شفاف بواقي للكاميرا من البولي يوريثين المقاوم للحرارة مع زوايا مضادة للصدمات مع شاشة حماية يدرجة امالة 5 دي لموبايل سامسونج جالاكسي A54 شبكة الجيل الخامس 5G من دلع موبايلك
# موبايل سامسونج جالاكسي A54 5G ثنائي شرائح الاتصال، نظام تشغيل اندرويد، ذاكرة RAM 8 جيجابايت، ذاكرة تخزين داخلية 256 جيجابايت، ليموني اوسيم، اسود
# موبايل سامسونج جالاكسيA25 شبكة لجيل الخامس 5G، يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة رام سعة 8 جيجا، تخزين 256 جيجابايت، أسود
# موبايل سامسونج جالاكسي M33، ثنائي شرائح الاتصال، ذاكرة رام 8 جيجابايت، تخزين 128 جيجابايت، الجيل الخامس 5G، بني
# سامسونج هاتف ذكي جالكسي اس 23 اف اي 5G ثنائي شرائح الاتصال بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا - جرافيت
# سامسونج هاتف ذكي جالكسي اس 23 اف اي 5G ثنائي شرائح الاتصال بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا - لون كريمي
# موبايل سامسونج جالاكسي A15 بشاشة 6.5 بوصة وشريحتين اتصال وذاكرة رام سعة 6 جيجابايت + ذاكرة ROM سعة 128 جيجابايت بشبكة الجيل الرابع 4G LTE - (لون أصفر)
# موبايل سامسونج جالاكسي A13 بشريحتين اتصال (سعة تخزين 64 جيجابايت/ 4 جيجابايت رام) - لون اسود
# موبايل سمارت سامسونج جالاكسي S24 الترا بنظام اندرويد بالذكاء الاصطناعي بذاكرة تخزين 256 جيجابايت وذاكرة رام 12 جيجابايت وكاميرا 200 ميجابيكسل بعمر بطارية طويل ، لون تيتانيوم فيوليت، بشريحتين
# سامسونج جوال جالكسي ايه 15 ثنائي شرائح الاتصال بذاكرة رام 4 جيجا وذاكرة روم 128 جيجا (6.5 انش) (4G LTE) - (اصفر)
# موبايل سامسونج جالاكسي A54 بشريحتي الاتصال، بنظام تشغيل اندرويد وذاكرة RAM 8 جيجابايت وذاكرة تخزين داخلية 256 جيجابايت، لون جرافيت، بشريحتين، جرافيت رائع
# سامسونج هاتف ذكي جالكسي زد فليب 5 بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا، اخضر فاتح - ضمان لمدة عام، بشريحتين
# سامسونج هاتف ذكي جالكسي زد فليب 5 بنظام اندرويد، ذاكرة رام 8 جيجابايت، ذاكرة روم 256 جيجابايت، ارجواني فاتح - ضمان لمدة عام، بشريحتين
# موبايل سمارت سامسونج جالاكسي S24 الترا بنظام اندرويد بالذكاء الصناعي وذاكرة تخزين 512 جيجابايت وذاكرة رام 12 جيجابايت وكاميرا 200 ميجابيكسل بعمر بطارية طويل وقلم ستايلس مدمج، لون تيتانيوم أسود
# موبايل سامسونج جالاكسي A15، شريحتين اتصال، ذاكرة رام سعة 4 جيحابايت، وذاكرة ROM سعة 128 جيجابايت (6.5 بوصة) (شبكة الجيل الرابع 4G LTE) - (أزرق فاتح)
# موبايل سامسونج جالاكسي A05 LTE بشريحتي اتصال، نظام تشغيل اندرويد، سعة تخزينية 128 جيجابايت، ذاكرة رام 6 جيجابايت، أسود
# موبايل سامسونج جالاكسي A15، شريحتين اتصال، ذاكرة RAM سعة 6 جيحا، وذاكرة ROM سعة 128 جيجا (6.5 بوصة) (4G LTE) - (أزرق فاتح)
# سامسونج هاتف ذكي جالكسي اس 23 اف اي 5G ثنائي شرائح الاتصال بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا - ارجواني
# موبايل نوكيا G21 اندرويد، بشريحتين اتصال، ذاكرة رام 4 جيجابايت، سعة تخزين 128 جيجابايت، شاشة 6.5 HD+، بطارية 5050 مللي امبير/الساعة، اندرويد 12 ريدي، خاصية التعرف على الوجه ومستشعر بصمة الاصبع - ازرق
# موبايل سامسونج جالاكسي A03 شبكة الجيل الرابع 4G بذاكرة داخلية 64 جيجابايت وذاكرة رام 4 جيجابايت، لون أزرق، بشريحتين
# موبايل سامسونج جالاكسي A04 بشريحتين اتصال وذاكرة رام 4 جيجابايت وسعة تخزينية 64 جيجابايت وشبكة LTE، نحاسي، برونزي
# موبايل سامسونج جالاكسي A34 بشريحتين اتصال وبنظام اندرويد وذاكرة RAM 8 جيجابايت وذاكرة تخزين 128 جيجابايت بلون فضي
# شاشة متوافقة مع سامسونج جالاكسي S22 الترا، 6.8 بوصة HD من الزجاج المقوى وواقي عدسة الكاميرا، واقي 9 ساعات - يدعم فتح القفل ببصمة الاصبع - لجالاكسي S22U- [2+2]، جالكسي اس 22 الترا AH175
# موبايل سامسونج جالاكسي A25 شبكة الجيل الخامس 5G، هاتف ذكي يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة RAM سعة 6 جيحا، وذاكرة تخزين 128 جيجا، لون أزرق فاتح
# موبايل سامسونج جالاكسي S24 الترا الذكي 512GB بالذكاء الاصطناعي بنظام اندرويد غير مقفل وكاميرا تكبير 50 ميجابكسل وعمر بطارية طويل وقلم ستايلس إصدار أمريكي، 2024، لون تيتانيوم جراي
# هاتف سامسونج مزدوج الشريحة SM-B310E- شبكة الجيل الثاني جي اس ام، ابيض، سامسونج اس ام، بشريحتين
# موبايل سامسونج جالاكسي A13 - بشريحتي اتصال، ذاكرة رام 4 جيجابايت، تخزين 128 جيجابايت، LTE - اسود
# موبايل سامسونج جالاكسي A05 LTE بشريحتي اتصال، نظام تشغيل اندرويد، سعة تخزينية 128 جيجابايت، ذاكرة رام 6 جيجابايت، أخضر فاتح
# موبايل سامسونج جالاكسيA25 شبكة لجيل الخامس 5G، يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة رام سعة 8 جيجا، تخزين 256 جيجابايت، أصفر
# موبايل سامسونج جالاكسي S22 بلس 5G ،256 جيجابايت وذاكرة RAM 8 جيجابايت وشريحة اتصال بنظام اندرويد مع شاحن سيارة لاسلكي وضمان سنة على الشاشة، ابيض، شريحتين
# سامسونج هاتف ذكي جالكسي زد فليب 5 بنظام اندرويد، ذاكرة رام 8 جيجابايت، ذاكرة روم 256 جيجابايت، لون كريمي - كفالة لمدة عام، بشريحتين
# موبايل سامسونج جالاكسي m33، بشريحتين اتصال، ذاكرة رام 8 جيجا، تخزين 128 جيجا، شبكة الجيل الخامس 5G، أزرق
# موبايل سامسونج جالاكسي A04s (لون أسود، ذاكرة رام 4 جيجابايت، سعة تخزينية 64 جيجابايت)
# جراب حماية لموبايل سامسونج جالاكسي زد فليب 5، جراب جلد ناعم ورفيع من البولي يوريثين الحراري المضاد الصدمات ومتوافق مع سامسونج جالاكسي زد فليب 5 من دلع موبايلك، الجيل الخامس 5G، 2023، لون رمادي
# دلـع موبايلك جراب شفاف لموبايل سامسونج جالاكسي S23 FE [متوافق مع ماج سيف] [مغناطيس قوي] [لا يصفر] غطاء جوال مغناطيسي رفيع ممتص للصدمات خفيف الوزن ومتين
# جراب موبايل سامسونج جالاكسي Z فولد 5، جلد البولي يوريثين + غلاف صلب من البولي كربونات من دلـع موبايلك، غطاء حماية رفيع للغاية ومتين لموبايل سامسونج جالاكسي Z فولد 5 الجيل الخامس 2023، أزرق
# شاحن حائط بمنفذ USB نوع C 33 واط GaN PD/QC PPS، شاحن للشحن السريع للغاية من لينوك لايفون 14/13/12، سامسونج S22/S21/S20، بكسل 7/6، ايباد برو/اير (أبيض)، يو اس بي

# %%
prices=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for price in prices:
    print(price.text)
# Out:
# 200
# 300
# 300
# 350
# 4,399
# 8,760
# 13,599
# 6,770
# 7,290
# 11,350
# 65,390
# 8,999
# 25,950
# 13,599
# 6,599
# 13,799
# 41,500
# 56,468
# 12,860
# 180
# 180
# 300
# 140
# 17,400
# 12,888
# 8,888
# 24,950
# 30,999
# 7,299
# 6,099
# 6,580
# 17,350
# 35,555
# 35,555
# 66,666
# 6,655
# 6,770
# 24,950
# 3,999
# 5,200
# 5,280
# 12,770
# 499
# 11,350
# 62,750
# 795
# 7,181
# 6,770
# 12,888
# 38,888
# 35,555
# 10,999
# 6,250
# 550
# 350
# 650
# 549

# %%
image=driver.find_elements("xpath","//img[@class='s-image']")
for img in image:
    print(img.get_attribute('src'))
# Out:
# https://m.media-amazon.com/images/I/611hkiII5IL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71gAGgBBmwL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/817OddHMhVL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71zpibdNRQL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51P4huodC+L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/514nSB8S9pL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71xU8w3fHJL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61OpPAw757L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61jBR+KUEDL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61jBR+KUEDL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61n8R-QRkUL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/7102NAlM6FL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51Cida8RecL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/617l83eY1rL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51kQgMblg9L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61isHdQ+TDL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/31sAgsqo2cL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71iBKcLHXFL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/719HV2e6-sL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/614qsXB-XUL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51Z1+GCah-L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71rcO57XdRL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71661esw2jL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61YfwhNq1yL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/716FwKy9FlL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61n8R-QRkUL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71rc4wx5L5L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61-E0V81kBL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61H2nUIKiNL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61hdrs3-MuL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71PJQjOX1dL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71DMZEvfSVL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61hdrs3-MuL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71xU8w3fHJL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61FD9JTbDmL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61XV1hG+m5L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71+WncNIt7L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61cl1NEIrdL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61xn0PNMjIL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61cl1NEIrdL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/610Q2I5Or8L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71AQ3qEZ-VL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61wC0e63kbL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81i6m64KmUL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71mHgTssjAL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71uUl5vJEyL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/614qsXB-XUL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71-EnPs+uQL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/51zTHAWglxL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61Bfs7DcHdL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71W7+KmTwYL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61EhQ+BnVgL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71m1Jx31JRL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/612HEsJQQ4L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/719Zb5jJA9L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91gYpDuqpYL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71nDwTWdUHL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71di+u+H5yL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71pdeUYKrTL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/41o7DPAR5kL._AC_UL320_.jpg

# %%
products=driver.find_elements(By.XPATH,"//span[@class='a-size-base-plus a-color-base a-text-normal']")

prices=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")


for i in products:
    print(i.text)
    
for i in prices:
    print(i.text)
# Out:
# جراب موبايل متوافق مع سامسونج جالاكسي A15 جلوبال ماجيك شيلد من البولي يوريثين الحراري + جراب سيليكون مضاد للصدمات لموبايل سامسونج جالاكسي A15 (رمادي داكن)
# جراب موبايل متوافق مع سامسونج جالاكسي M51، جراب جلد متعددة الوظائف قابل للطي أفقيًا مع فتحة للبطاقات وحامل ومحفظة لموبايل سامسونج جالاكسي M51 (أسود)
# جراب حماية خلفي مغناطيسي من الجلد الفاخر من جيهود متوافق مع سامسونج جالاكسي S23 FE (بني)
# جراب موبايل متوافق مع سامسونج جالاكسي S23 FE شبكة الجيل الخامس 5G، جراب جلد افقي متعدد الوظائف، مع فتحة للبطاقات وحامل ومحفظة لسامسونج جالاكسي S23 FE 5G (أسود)
# موبايل سامسونج A04S ذاكرة رام 3 جيجابايت، ذاكرة داخلية 32 جيجابايت - لون أسود، سامسونج ايه 04 اس، شريحتين
# موبايل سامسونج جالاكسي A15 بشاشة 6.5 بوصة بشريحتين اتصال وذاكرة رام سعة 8 جيجابايت + ذاكرة ROM سعة 256 جيجابايت بشبكة الجيل الرابع 4G - (لون أسود)
# موبايل سامسونج جالاكسي A54 (5G) بشريحتين اتصال، نظام تشغيل اندرويد، ذاكرة RAM 8 جيجابايت، ذاكرة تخزين داخلية 128 جيجابايت، اوسيم رمادي جرافيت
# موبايل سامسونج جالاكسي A05 LTE بشريحتي اتصال، نظام تشغيل اندرويد، سعة تخزينية 128 جيجابايت، ذاكرة رام 6 جيجابايت، فضي
# موبايل سامسونج جالاكسي A05s، يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة رام سعة 4 جيحا، وذاكرة تخزين 128 جيجا، أسود
# موبايل سامسونج جالاكسي A05s، هاتف ذكي يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة RAM سعة 6 جيحا، وذاكرة تخزين 128 جيجا، أسود
# موبايل سامسونج جالاكسي A25 شبكة الجيل الخامس 5G بنظام اندرويد بشريحتين اتصال وذاكرة تخزين 128 جيجا وذاكرة رام سعة 6 جيجا، أسود
# سامسونج هاتف ذكي جالكسي زد فولد 5 بنظام اندرويد، ذاكرة رام 12 جيجا، ذاكرة روم 256 جيجا، اسود فانتوم - ضمان لمدة عام، بشريحتين
# موبايل سامسونج جالاكسي A15 بشاشة 6.5 بوصة بشريحتين شبكة الجيل الرابع 4G LTE وذاكرة رام سعة 8 جيجابايت + ذاكرة ROM سعة 256 جيجابايت - لون أزرق فاتح
# سامسونج هاتف ذكي جالكسي اس 23 اف اي 5G ثنائي شرائح الاتصال بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا - اخضر فاتح
# موبايل سامسونج جالاكسي A54 اندرويد بشريحتين اتصال - ذاكرة رام 8 جيجابايت - 128 جيجابايت - 5G - - لون اوسوم لايم
# موبايل سامسونج جالاكسي A15 بشريحتين اتصال وذاكرة رام بسعة 4 جيجابايت وذاكرة ROM بسعة 128 جيجابايت بشبكة الجيل الرابع 4G وشاشة حجم 6.5 بوصة - (لون اسود أزرق)
# موبايل سامسونج جالاكسي A34 شبكة الجيل الخامس 5G بشريحتين اتصال وذاكرة رام 8 جيجابايت وذاكرة داخلية 256 جيجابايت بلون فضي
# موبايل سامسونج جالاكسي S23 الترا، بذاكرة رام 12 جيجا، موبايل ذكي يعمل بنظام اندرويد بشريحتين اتصال لون أسود فانتوم
# موبايل سمارت سامسونج جالاكسي S24 الترا بنظام اندرويد بالذكاء الاصطناعي بذاكرة تخزين 256 جيجابايت وذاكرة رام 12 جيجابايت وكاميرا 200 ميجابيكسل بعمر بطارية طويل وقلم ستايلس، لون تيتانيوم بلاك، بشريحتين
# موبايل سامسونج جالاكسي A25 شبكة الجيل الخامس 5G، بنظام اندرويد، بشريحتين اتصال، ذاكرة رام سعة 8 جيحا، وذاكرة تخزين 256 جيجا، لون أزرق فاتح
# جراب موبايل متوافق مع سامسونج جالاكسي A15 [تصميم خلية النحل] حماية من السقوط، جراب حماية رفيع للغاية من البولي يوريثين الحراري + بولي كربونات سيليكون شفاف، جراب مضاد للصدمات لموبايل سامسونج جالاكسي
# جراب بانك ارمور 2 في 1 متوافق مع موبايل سامسونج جالاكسي S23، من البولي كربونات والبولي يوريثين المقاوم للحرارة مضاد للصدمات بحامل غير مرئي لموبايل سامسونج جالاكسي S23 FE (أسود)
# جراب خلفي مغناطيسي من الجلد الفاخر متوافق مع سامسونج جالاكسي S23 FE، جراب حماية مغناطيسي لموبايل سامسونج جالاكسي S23 FE (بني فاتح)
# جراب حماية غوريلا سيليكون شفاف بواقي للكاميرا من البولي يوريثين المقاوم للحرارة مع زوايا مضادة للصدمات مع شاشة حماية يدرجة امالة 5 دي لموبايل سامسونج جالاكسي A54 شبكة الجيل الخامس 5G من دلع موبايلك
# موبايل سامسونج جالاكسي A54 5G ثنائي شرائح الاتصال، نظام تشغيل اندرويد، ذاكرة RAM 8 جيجابايت، ذاكرة تخزين داخلية 256 جيجابايت، ليموني اوسيم، اسود
# موبايل سامسونج جالاكسيA25 شبكة لجيل الخامس 5G، يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة رام سعة 8 جيجا، تخزين 256 جيجابايت، أسود
# موبايل سامسونج جالاكسي M33، ثنائي شرائح الاتصال، ذاكرة رام 8 جيجابايت، تخزين 128 جيجابايت، الجيل الخامس 5G، بني
# سامسونج هاتف ذكي جالكسي اس 23 اف اي 5G ثنائي شرائح الاتصال بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا - جرافيت
# سامسونج هاتف ذكي جالكسي اس 23 اف اي 5G ثنائي شرائح الاتصال بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا - لون كريمي
# موبايل سامسونج جالاكسي A15 بشاشة 6.5 بوصة وشريحتين اتصال وذاكرة رام سعة 6 جيجابايت + ذاكرة ROM سعة 128 جيجابايت بشبكة الجيل الرابع 4G LTE - (لون أصفر)
# موبايل سامسونج جالاكسي A13 بشريحتين اتصال (سعة تخزين 64 جيجابايت/ 4 جيجابايت رام) - لون اسود
# موبايل سمارت سامسونج جالاكسي S24 الترا بنظام اندرويد بالذكاء الاصطناعي بذاكرة تخزين 256 جيجابايت وذاكرة رام 12 جيجابايت وكاميرا 200 ميجابيكسل بعمر بطارية طويل ، لون تيتانيوم فيوليت، بشريحتين
# سامسونج جوال جالكسي ايه 15 ثنائي شرائح الاتصال بذاكرة رام 4 جيجا وذاكرة روم 128 جيجا (6.5 انش) (4G LTE) - (اصفر)
# موبايل سامسونج جالاكسي A54 بشريحتي الاتصال، بنظام تشغيل اندرويد وذاكرة RAM 8 جيجابايت وذاكرة تخزين داخلية 256 جيجابايت، لون جرافيت، بشريحتين، جرافيت رائع
# سامسونج هاتف ذكي جالكسي زد فليب 5 بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا، اخضر فاتح - ضمان لمدة عام، بشريحتين
# سامسونج هاتف ذكي جالكسي زد فليب 5 بنظام اندرويد، ذاكرة رام 8 جيجابايت، ذاكرة روم 256 جيجابايت، ارجواني فاتح - ضمان لمدة عام، بشريحتين
# موبايل سمارت سامسونج جالاكسي S24 الترا بنظام اندرويد بالذكاء الصناعي وذاكرة تخزين 512 جيجابايت وذاكرة رام 12 جيجابايت وكاميرا 200 ميجابيكسل بعمر بطارية طويل وقلم ستايلس مدمج، لون تيتانيوم أسود
# موبايل سامسونج جالاكسي A15، شريحتين اتصال، ذاكرة رام سعة 4 جيحابايت، وذاكرة ROM سعة 128 جيجابايت (6.5 بوصة) (شبكة الجيل الرابع 4G LTE) - (أزرق فاتح)
# موبايل سامسونج جالاكسي A05 LTE بشريحتي اتصال، نظام تشغيل اندرويد، سعة تخزينية 128 جيجابايت، ذاكرة رام 6 جيجابايت، أسود
# موبايل سامسونج جالاكسي A15، شريحتين اتصال، ذاكرة RAM سعة 6 جيحا، وذاكرة ROM سعة 128 جيجا (6.5 بوصة) (4G LTE) - (أزرق فاتح)
# سامسونج هاتف ذكي جالكسي اس 23 اف اي 5G ثنائي شرائح الاتصال بنظام اندرويد، ذاكرة رام 8 جيجا، ذاكرة روم 256 جيجا - ارجواني
# موبايل نوكيا G21 اندرويد، بشريحتين اتصال، ذاكرة رام 4 جيجابايت، سعة تخزين 128 جيجابايت، شاشة 6.5 HD+، بطارية 5050 مللي امبير/الساعة، اندرويد 12 ريدي، خاصية التعرف على الوجه ومستشعر بصمة الاصبع - ازرق
# موبايل سامسونج جالاكسي A03 شبكة الجيل الرابع 4G بذاكرة داخلية 64 جيجابايت وذاكرة رام 4 جيجابايت، لون أزرق، بشريحتين
# موبايل سامسونج جالاكسي A04 بشريحتين اتصال وذاكرة رام 4 جيجابايت وسعة تخزينية 64 جيجابايت وشبكة LTE، نحاسي، برونزي
# موبايل سامسونج جالاكسي A34 بشريحتين اتصال وبنظام اندرويد وذاكرة RAM 8 جيجابايت وذاكرة تخزين 128 جيجابايت بلون فضي
# شاشة متوافقة مع سامسونج جالاكسي S22 الترا، 6.8 بوصة HD من الزجاج المقوى وواقي عدسة الكاميرا، واقي 9 ساعات - يدعم فتح القفل ببصمة الاصبع - لجالاكسي S22U- [2+2]، جالكسي اس 22 الترا AH175
# موبايل سامسونج جالاكسي A25 شبكة الجيل الخامس 5G، هاتف ذكي يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة RAM سعة 6 جيحا، وذاكرة تخزين 128 جيجا، لون أزرق فاتح
# موبايل سامسونج جالاكسي S24 الترا الذكي 512GB بالذكاء الاصطناعي بنظام اندرويد غير مقفل وكاميرا تكبير 50 ميجابكسل وعمر بطارية طويل وقلم ستايلس إصدار أمريكي، 2024، لون تيتانيوم جراي
# هاتف سامسونج مزدوج الشريحة SM-B310E- شبكة الجيل الثاني جي اس ام، ابيض، سامسونج اس ام، بشريحتين
# موبايل سامسونج جالاكسي A13 - بشريحتي اتصال، ذاكرة رام 4 جيجابايت، تخزين 128 جيجابايت، LTE - اسود
# موبايل سامسونج جالاكسي A05 LTE بشريحتي اتصال، نظام تشغيل اندرويد، سعة تخزينية 128 جيجابايت، ذاكرة رام 6 جيجابايت، أخضر فاتح
# موبايل سامسونج جالاكسيA25 شبكة لجيل الخامس 5G، يعمل بنظام اندرويد، بشريحتين اتصال، ذاكرة رام سعة 8 جيجا، تخزين 256 جيجابايت، أصفر
# موبايل سامسونج جالاكسي S22 بلس 5G ،256 جيجابايت وذاكرة RAM 8 جيجابايت وشريحة اتصال بنظام اندرويد مع شاحن سيارة لاسلكي وضمان سنة على الشاشة، ابيض، شريحتين
# سامسونج هاتف ذكي جالكسي زد فليب 5 بنظام اندرويد، ذاكرة رام 8 جيجابايت، ذاكرة روم 256 جيجابايت، لون كريمي - كفالة لمدة عام، بشريحتين
# موبايل سامسونج جالاكسي m33، بشريحتين اتصال، ذاكرة رام 8 جيجا، تخزين 128 جيجا، شبكة الجيل الخامس 5G، أزرق
# موبايل سامسونج جالاكسي A04s (لون أسود، ذاكرة رام 4 جيجابايت، سعة تخزينية 64 جيجابايت)
# جراب حماية لموبايل سامسونج جالاكسي زد فليب 5، جراب جلد ناعم ورفيع من البولي يوريثين الحراري المضاد الصدمات ومتوافق مع سامسونج جالاكسي زد فليب 5 من دلع موبايلك، الجيل الخامس 5G، 2023، لون رمادي
# دلـع موبايلك جراب شفاف لموبايل سامسونج جالاكسي S23 FE [متوافق مع ماج سيف] [مغناطيس قوي] [لا يصفر] غطاء جوال مغناطيسي رفيع ممتص للصدمات خفيف الوزن ومتين
# جراب موبايل سامسونج جالاكسي Z فولد 5، جلد البولي يوريثين + غلاف صلب من البولي كربونات من دلـع موبايلك، غطاء حماية رفيع للغاية ومتين لموبايل سامسونج جالاكسي Z فولد 5 الجيل الخامس 2023، أزرق
# شاحن حائط بمنفذ USB نوع C 33 واط GaN PD/QC PPS، شاحن للشحن السريع للغاية من لينوك لايفون 14/13/12، سامسونج S22/S21/S20، بكسل 7/6، ايباد برو/اير (أبيض)، يو اس بي
# 200
# 300
# 300
# 350
# 4,399
# 8,760
# 13,599
# 6,770
# 7,290
# 11,350
# 65,390
# 8,999
# 25,950
# 13,599
# 6,599
# 13,799
# 41,500
# 56,468
# 12,860
# 180
# 180
# 300
# 140
# 17,400
# 12,888
# 8,888
# 24,950
# 30,999
# 7,299
# 6,099
# 6,580
# 17,350
# 35,555
# 35,555
# 66,666
# 6,655
# 6,770
# 24,950
# 3,999
# 5,200
# 5,280
# 12,770
# 499
# 11,350
# 62,750
# 795
# 7,181
# 6,770
# 12,888
# 38,888
# 35,555
# 10,999
# 6,250
# 550
# 350
# 650
# 549

# %%
import csv
with open('amazon_products.csv','w',encoding='utf-8',newline='')as csvfile:
    csvwriter=csv.writer(csvfile,delimiter=',')
    csvwriter.writerow(['المنتجات','prices'])
    for i in range(0,len(prices)):
        csvwriter.writerow([products[i].text,prices[i].text])
